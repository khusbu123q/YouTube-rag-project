# %%
from pathlib import Path
import pandas as pd
from data_ingestion import load_all_raw
from feature_engineering import build_subject_snapshot
from scoring import compute_clean_patient_flags, compute_dqi

raw = load_all_raw()
subject_df = build_subject_snapshot(raw)
subject_df = compute_clean_patient_flags(subject_df)
subject_df = compute_dqi(subject_df)

subject_df.to_parquet("data/processed/subject_site_snapshot.parquet", index=False)

# Summary stats
subject_df["dqi"].describe()
subject_df["dqi_band"].value_counts(normalize=True)

# Site-level aggregation
site_df = subject_df.groupby(["project_name", "site_id"], as_index=False).agg(
    mean_dqi=("dqi", "mean"),
    pct_clean=("clean_patient", "mean"),
    n_subjects=("subject_id", "nunique"),
    n_red=("dqi_band", lambda x: (x=="Red").sum())
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 8
#       5 from scoring import compute_clean_patient_flags, compute_dqi
#       7 raw = load_all_raw()
# ----> 8 subject_df = build_subject_snapshot(raw)
#       9 subject_df = compute_clean_patient_flags(subject_df)
#      10 subject_df = compute_dqi(subject_df)
#
# File ~\Desktop\MyFiles\Pycharm\Novartis_hackathon\feature_engineering.py:127, in build_subject_snapshot(raw)
#     124 def build_subject_snapshot(raw: dict) -> pd.DataFrame:
#     125     cpid_feat = engineer_from_cpid(raw["cpid"])
# --> 127     visits_feat = aggregate_visits(raw["visits"])
#     128     missing_pages_feat = aggregate_missing_pages(raw["missing_pages"])
#     129     lab_feat = aggregate_lab_issues(raw["missing_lab"])
#
# File ~\Desktop\MyFiles\Pycharm\Novartis_hackathon\feature_engineering.py:22, in aggregate_visits(visits)
#      11 # columns already cleaned in ingestion
#      12 # expected cleaned names:
#      13 # site, subject, visit, days_outstanding
#      15 df = df.rename(columns={
#      16     "site": "site_id",
#      17     "subject": "subject_id"
#      18 })
#      20 grp = df.groupby(
#      21     ["site_id", "subject_id"], as_index=False
# ---> 22 ).agg(
#      23     n_missing_visits=("visit", "count"),
#      24     days_outstanding_max=("days_outstanding", "max")
#      25 )
#      27 return grp
#
# File ~\Desktop\MyFiles\Pycharm\.venv\Lib\site-packages\pandas\core\groupby\generic.py:2291, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    2288     kwargs["engine_kwargs"] = engine_kwargs
#    2290 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 2291 result = op.agg()
#    2292 if not is_dict_like(func) and result is not None:
#    2293     # GH #52849
#    2294     if not self.as_index and is_list_like(func):
#
# File ~\Desktop\MyFiles\Pycharm\.venv\Lib\site-packages\pandas\core\apply.py:294, in Apply.agg(self)
#     291     return self.apply_str()
#     293 if is_dict_like(func):
# --> 294     return self.agg_dict_like()
#     295 elif is_list_like(func):
#     296     # we require a list, but not a 'str'
#     297     return self.agg_list_like()
#
# File ~\Desktop\MyFiles\Pycharm\.venv\Lib\site-packages\pandas\core\apply.py:511, in Apply.agg_dict_like(self)
#     503 def agg_dict_like(self) -> DataFrame | Series:
#     504     """
#     505     Compute aggregation in the case of a dict-like argument.
#     506
#    (...)    509     Result of aggregation.
#     510     """
# --> 511     return self.agg_or_apply_dict_like(op_name="agg")
#
# File ~\Desktop\MyFiles\Pycharm\.venv\Lib\site-packages\pandas\core\apply.py:1677, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1672     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1674 with com.temp_setattr(
#    1675     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1676 ):
# -> 1677     result_index, result_data = self.compute_dict_like(
#    1678         op_name, selected_obj, selection, kwargs
#    1679     )
#    1680 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1681 return result
#
# File ~\Desktop\MyFiles\Pycharm\.venv\Lib\site-packages\pandas\core\apply.py:550, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     548 is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#     549 func = cast(AggFuncTypeDict, self.func)
# --> 550 func = self.normalize_dictlike_arg(op_name, selected_obj, func)
#     552 is_non_unique_col = (
#     553     selected_obj.ndim == 2
#     554     and selected_obj.columns.nunique() < len(selected_obj.columns)
#     555 )
#     557 if selected_obj.ndim == 1:
#     558     # key only used for output
#
# File ~\Desktop\MyFiles\Pycharm\.venv\Lib\site-packages\pandas\core\apply.py:762, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     759     cols = Index(list(func.keys())).difference(obj.columns, sort=True)
#     760     if len(cols) > 0:
#     761         # GH 58474
# --> 762         raise KeyError(f"Label(s) {list(cols)} do not exist")
#     764 aggregator_types = (list, tuple, dict)
#     766 # if we have a dict of any non-scalars
#     767 # eg. {'A' : ['mean']}, normalize all to
#     768 # be list-likes
#     769 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Label(s) ['days_outstanding'] do not exist"

# %%
# %load_ext autoreload
# %autoreload 2

from data_ingestion import DATA_DIR, find_file, load_all_raw

print("DATA_DIR:", DATA_DIR)
for f in DATA_DIR.glob("*.xls*"):
    print(f.name)

raw = load_all_raw()

# %%
from pathlib import Path
from data_ingestion import DATA_DIR

for f in DATA_DIR.glob("*.xls*"):
    print(f.name)
